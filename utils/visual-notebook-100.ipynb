# %% [markdown]
# # Data visualisation for extracted data

# %%
from visual import *
import torch

# %% [markdown]
# ## Loading accuracies

# %%
paths = [
    "../saved/BSUTest-2048-2048-PermutedMNIST-lr-0.025-scale-0.921-temperature-1-init_lambda-0-num_mcmc_samples-1/2024-01-31-0-BSUTest-2048-2048-PermutedMNIST-lr-0.025-scale-0.921-temperature-1-init_lambda-0-num_mcmc_samples-1-v3/2024-01-31-BSUTest-2048-2048-PermutedMNIST-lr-0.025-scale-0.921-temperature-1-init_lambda-0-num_mcmc_samples-1-accuracy-v1.pt",
]

# %%
accuracies = []
for path in paths:
    accuracies.append(torch.load(path))

# %%
visualize_task_frame("Accuracy", accuracies, "test", 1, 10)
visualize_task_frame("Accuracy", accuracies, "test", 91, 100)
