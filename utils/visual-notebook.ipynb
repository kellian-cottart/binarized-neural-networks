# %% [markdown]
# # Data visualisation for extracted data

# %%
from visual import *
import torch

# %% [markdown]
# ## Loading accuracies

# %%
paths = [
    "../saved/BayesianNN - 100 - 100/2023-11-24-0-BayesianNN - 100 - 100-v1/2023-11-24-BayesianNN - 100 - 100-accuracy-v1.pt",
    "../saved/BayesianNN - 100 - 100/2023-11-24-1-BayesianNN - 100 - 100-v1/2023-11-24-BayesianNN - 100 - 100-accuracy-v1.pt",
    "../saved/BayesianNN - 100 - 100/2023-11-24-2-BayesianNN - 100 - 100-v1/2023-11-24-BayesianNN - 100 - 100-accuracy-v1.pt",
    "../saved/BayesianNN - 100 - 100/2023-11-24-3-BayesianNN - 100 - 100-v1/2023-11-24-BayesianNN - 100 - 100-accuracy-v1.pt",
    "../saved/BayesianNN - 100 - 100/2023-11-24-4-BayesianNN - 100 - 100-v1/2023-11-24-BayesianNN - 100 - 100-accuracy-v1.pt",
]

# %%
accuracies = []
for path in paths:
    accuracies.append(torch.load(path))
print(accuracies[0])
# Out:
# [[0.1306, 0.1155], [0.1618, 0.1123], [0.1656, 0.1972], [0.1752, 0.2511]]

# %%
visualize_sequential("test", accuracies, "test")
