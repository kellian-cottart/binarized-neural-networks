# %% [markdown]
# # Data visualisation for extracted data

# %%
from visual import *
import torch

# %% [markdown]
# ## Loading accuracies

# %%
paths = [
    "../saved/BayesianNN-200-200-PermutedMNIST-10/2023-11-29-0-BayesianNN-200-200-PermutedMNIST-10-v1/2023-11-29-BayesianNN-200-200-PermutedMNIST-10-accuracy-v1.pt",
    "../saved/BayesianNN-200-200-PermutedMNIST-10/2023-11-29-1-BayesianNN-200-200-PermutedMNIST-10-v1/2023-11-29-BayesianNN-200-200-PermutedMNIST-10-accuracy-v1.pt",
    "../saved/BayesianNN-200-200-PermutedMNIST-10/2023-11-29-2-BayesianNN-200-200-PermutedMNIST-10-v1/2023-11-29-BayesianNN-200-200-PermutedMNIST-10-accuracy-v1.pt",
    "../saved/BayesianNN-200-200-PermutedMNIST-10/2023-11-29-4-BayesianNN-200-200-PermutedMNIST-10-v1/2023-11-29-BayesianNN-200-200-PermutedMNIST-10-accuracy-v1.pt",
]

# %%
accuracies = []
for path in paths:
    accuracies.append(torch.load(path))

# %%
visualize_sequential("test", accuracies, "test")
